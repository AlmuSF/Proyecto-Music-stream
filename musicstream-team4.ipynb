# %%
#El primer paso es importar las librerías.

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests as req
from requests.auth import HTTPBasicAuth

# %%
#A continuación, para acceder a la API de Spotify necesitamos algunos datos como el Client ID, Client Secret y, a raíz de estos, un token.
#¡Atención! En este caso necesitamos indicar el tipo de token para poder avanzar, "Bearer".

# %%
client_id = "86dd658cb09e43338d8b0cc63d8e7921"
client_secret = "83bf6e540fa94fcc92944167a4a9ccd5"
url = "https://accounts.spotify.com/api/token"
data = {
    "grant_type": "client_credentials"
}
response = requests.post(url, data=data, auth=HTTPBasicAuth(client_id, client_secret))
if response.status_code == 200:
    token = response.json()["access_token"]
    print("Token de acceso:", token)
else:
    print("Error:", response.status_code)
    print(response.text)
# Out:
# Token de acceso: BQBmGyCi9Gd6KUNMSS_EGNYsbtMMCFruu7_ipYrOdpGCKMd7vmdhk1xaM03A9z2hW-09SSng1HbR3D-eEBItJ5HoNKtXFj_m1LVhwbXCeoKVhAH6AA02dNCYQ-puGM84dDUyZkWC874

# %%
# Obtenemos los endpoints y realizamos las llamadas

# %%
token_spotify = "Bearer BQBmGyCi9Gd6KUNMSS_EGNYsbtMMCFruu7_ipYrOdpGCKMd7vmdhk1xaM03A9z2hW-09SSng1HbR3D-eEBItJ5HoNKtXFj_m1LVhwbXCeoKVhAH6AA02dNCYQ-puGM84dDUyZkWC874"
api_key_albums = "https://api.spotify.com/v1/albums/{id}"
id_album = "4aawyAB9vmqN3uQ7FjRGTy"

api_key_tracks = "https://api.spotify.com/v1/tracks/{id}"
id_tracks = "11dFghVXANMlKmJXsNCbNl"

# %%
#En primer lugar, los álbumes

# %%
twenties_albums = req.get(f"https://api.spotify.com/v1/albums/{id_album}", headers = {"Authorization": token_spotify})

print(twenties_albums.status_code)
print(twenties_albums.reason)
info_albums = twenties_albums.json()
print(info_albums)
# Out:
# 200
# OK
# ...

# %%
#En segundo lugar, los tracks

# %%
twenties_tracks = req.get(f"https://api.spotify.com/v1/tracks/{id_tracks}", headers = {"Authorization": token_spotify})

print(twenties_tracks.status_code)
print(twenties_tracks.reason)
info_tracks = twenties_tracks.json()
print(info_tracks)
# Out:
# 200
# OK
# ...

# %%
Extraer canciones y álbumes lanzados entre 2000 y 2024.

Elegir un rango de 5 años para extraer datos (por ejemplo de 2002 a 2007).

Seleccionar 4 géneros musicales para el desarrollo de este proyecto.

Extraer la siguiente información:

Artista.

Género musical.

Tipo (canción o álbum).

Nombre.

Año de lanzamiento.

ID.

# %%
#Estamos buscando las canciones que sean de genero rock del 2020, la consulta lo ponemos en la query
datos = sp.search(q="genre:pop,rock,reggaeton,indie year:2020-2024-", type="artist,track", limit=10, offset=0)
data_track_album = sp.search(q="genre:pop,rock,reggaeton,indie year:2020-2024-", type='artist,album', limit=10, offset=0)

#aqui vemos que me trae como respuesta, y vemos en el resultado qeu viene dentro de tracks
datos.keys()

# %%
#Estamos buscando las canciones que sean de genero rock del 2020, la consulta lo ponemos en la query
datos_pop = sp.search(q="genre:pop year:2020-2024", type="track", limit=10, offset=0)
datos_rock = sp.search(q="genre:rock year:2020-2024", type="track", limit=10, offset=0)
datos_reggaeton = sp.search(q="genre:reggaeton year:2020-2024", type="track", limit=10, offset=0)
datos_indie = sp.search(q="genre:indie year:2020-2024", type="track", limit=10, offset=0)

#aqui vemos que me trae como respuesta, y vemos en el resultado qeu viene dentro de tracks
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos_pop
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=genre%3Apop%20year%3A2020-2024&type=track',
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?offset=10&limit=10&query=genre%3Apop%20year%3A2020-2024&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#        'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#        'id': '2LRoIwlKmHjgvigdNGBHNo',
#        'name': 'Feid',
#        'type': 'artist',
#        'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
# ...

# %%
datos_rock
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=genre%3Arock%20year%3A2020-2024&type=track',
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?offset=10&limit=10&query=genre%3Arock%20year%3A2020-2024&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wwiu1wnq1W8AMYbWuRFDH'},
#        'href': 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH',
#        'id': '2Wwiu1wnq1W8AMYbWuRFDH',
#        'name': 'Arde Bogotá',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
# ...

# %%
datos_reggaeton
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=genre%3Areggaeton%20year%3A2020-2024&type=track',
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?offset=10&limit=10&query=genre%3Areggaeton%20year%3A2020-2024&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#        'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#        'id': '790FomKkXshlbRYZFtlgla',
#        'name': 'KAROL G',
#        'type': 'artist',
#        'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
# ...

# %%
datos_indie
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=10&query=genre%3Aindie%20year%3A2020-2024&type=track',
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?offset=10&limit=10&query=genre%3Aindie%20year%3A2020-2024&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wwiu1wnq1W8AMYbWuRFDH'},
#        'href': 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH',
#        'id': '2Wwiu1wnq1W8AMYbWuRFDH',
#        'name': 'Arde Bogotá',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
# ...

# %%
# Aqui veo la info que viene en tracks datos[`tracks`], pero no es suficiente, al parecer la información viene en items, entonces hago un datos['tracks']['items'], como me sigue sin ver bien solo voy a ver un elemento a ver como se ve y hago datos['tracks']['items'][0]
datos['tracks']['items'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Aqui veo la info que viene en tracks datos[`tracks`], pero no es suficiente, al parecer la información viene en items, entonces hago un datos['tracks']['items'], como me sigue sin ver bien solo voy a ver un elemento a ver como se ve y hago datos['tracks']['items'][0]
# ----> 2 datos['tracks']['items'][0]
#
# IndexError: list index out of range

# %%
track_only_one = datos['tracks']['items'][2]

# %%
track_only_one

# %%
# Limpiar, transformar, añadir
# Pasar los datos a un data frame:
    # df_municipios = pd.DataFrame(resultado)
    # df_municipios
